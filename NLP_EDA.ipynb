# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from bs4 import BeautifulSoup

# %%
# Functions file for personality prediction file

import unicodedata
from nltk.tokenize import word_tokenize
import pandas as pd
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
import string
import re
from bs4 import BeautifulSoup

REPLACE_BY_SPACE_RE = re.compile('[/(){}\\[\]\|?@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
punctuation_ = set(string.punctuation)
stopwords_ = set(stopwords.words('english'))

def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii.decode()

def filter_tokens(sent):
    return ([w for w in sent if not w in stopwords_ and not w in punctuation_])

def remove_link(sent):
    return [s for s in sent if 'http' not in s]

def wt(text):
    return [word_tokenize(sent) for sent in text.split()]

def flatten(lst):
    return [item for sublist in lst for item in sublist]

def snow_stem(text):
    snowball = SnowballStemmer('english')
    return [snowball.stem(word) for word in text]

def rm_punc(sent):
    return [w for w in sent if not w in punctuation_]

def clean_text(text):
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in stopwords_)
    return text

def clean_df(df):
    """Normalize the data, change all letters to lower case, split into 
    sentences,remove website links, tokenize words into a new dataframe then:
    filter punctuation, filter stopwords, stemminize
    INPUT
    --------------
    df = Pandas DataFrame
    OUTPUT
    --------------
    word = Pandas DataFrames
    ______________
    """
    newdf = df.copy()
    newdf.posts = newdf.posts.apply(lambda x: remove_accents(x).lower())
    newdf = pd.DataFrame((newdf.type,newdf.posts.apply(lambda x: x.split('|||')))).T
    newdf.posts = newdf.posts.apply(lambda x: remove_link(x))
    newdf.posts = newdf.posts.apply(lambda x: ' '.join(x))
    newdf.posts = newdf.posts.apply(lambda x: clean_text(x))
    newdf.posts = newdf.posts.apply(lambda x: wt(x))
    newdf.posts = newdf.posts.apply(lambda x: flatten(x))
    newdf.posts = newdf.posts.apply(lambda x: snow_stem(x))
    newdf.posts = newdf.posts.apply(lambda x: ' '.join(x))
    return newdf

# %%
df = pd.read_json('data/data.json')

# %%
def fraud(string):
    if 'fraud' in string:
        return True
    else:
        return False

# %%
df['fraud'] = df.acct_type.apply(lambda x: fraud(x))

# %%
df.columns
# Out:
# Index(['acct_type', 'approx_payout_date', 'body_length', 'channels', 'country',
#        'currency', 'delivery_method', 'description', 'email_domain',
#        'event_created', 'event_end', 'event_published', 'event_start',
#        'fb_published', 'gts', 'has_analytics', 'has_header', 'has_logo',
#        'listed', 'name', 'name_length', 'num_order', 'num_payouts',
#        'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
#        'payee_name', 'payout_type', 'previous_payouts', 'sale_duration',
#        'sale_duration2', 'show_map', 'ticket_types', 'user_age',
#        'user_created', 'user_type', 'venue_address', 'venue_country',
#        'venue_latitude', 'venue_longitude', 'venue_name', 'venue_state',
#        'fraud'],
#       dtype='object')

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
#                  email_domain  event_created   event_end  event_published  \
# 0                   gmail.com     1262739706  1265630400     1.263110e+09
# 1                     ruf.org     1293832670  1296288000     1.293833e+09
# 2              pvsd.k12.ca.us     1291090956  1295740800     1.291092e+09
# 3        irishtabletennis.com     1360681570  1388534400     1.360683e+09
# 4  artsandbusinesscouncil.org     1291994666  1297468800     1.291995e+09
#
#    event_start  fb_published      gts  ...  \
# 0   1265594400             0     0.00  ...
# 1   1296255600             0   868.02  ...
# 2   1295713800             0  3500.00  ...
# 3   1360702800             0  1167.35  ...
# 4   1297440000             1  2313.15  ...
#
#                                     previous_payouts  sale_duration  \
# 0                                                 []           29.0
# 1  [{'name': 'RUF', 'created': '2010-10-01 01:10:...           28.0
# 2  [{'name': 'Danielle Severn', 'created': '2010-...           54.0
# 3  [{'name': '', 'created': '2010-11-09 01:10:15'...            0.0
# 4  [{'name': 'Arts and Business Council or Greate...           63.0
#
#    sale_duration2 show_map                                       ticket_types  \
# 0              33        1  [{'event_id': 527017, 'cost': 25.0, 'availabil...
# 1              28        0  [{'event_id': 786878, 'cost': 35.0, 'availabil...
# 2              54        0  [{'event_id': 787337, 'cost': 93.51, 'availabi...
# 3               0        0  [{'event_id': 885645, 'cost': 25.0, 'availabil...
# 4              63        0  [{'event_id': 1114349, 'cost': 150.0, 'availab...
#
#    user_age  user_created  user_type                 venue_address  \
# 0        36    1259613950          1         717 Washington Avenue
# 1       149    1280942776          3
# 2       214    1272559388          3  10100 Pioneer Blvd Suite 100
# 3       889    1283870102          3
# 4        35    1288984065          3        One Marina Park Drive
#
#   venue_country  venue_latitude venue_longitude  \
# 0            US       25.777471      -80.133433
# 1            US       32.776566      -79.930922
# 2            US       33.944201     -118.080419
# 3          None             NaN             NaN
# 4            US       42.353848      -71.044276
#
#                                venue_name venue_state  fraud
# 0             INK Nightclub - South Beach          FL   True
# 1                 The Charleston, SC area          SC  False
# 2  Los Angeles County Office of Education          CA  False
# 3                                    None        None  False
# 4                       Fish & Richardson          MA  False
#
# [5 rows x 45 columns]

# %%
df['description'] = df.description.apply(lambda x: BeautifulSoup(x).text)

# %%
def preprocess(text):
    text = text.str.replace('\n', '')
    text = text.str.replace('www','')
    text = text.str.replace('com','')
    text = text.str.replace('http', '')
    text = text.str.replace('00', '')
    text = text.str.replace('30', '')
    text = text.str.replace('15', '')
    text = text.str.replace('10','')
    return text
df['description'] = preprocess(df.description)

# %%
df.acct_type.value_counts()
# Out:
# premium             12373
# fraudster_event       851
# fraudster             437
# spammer_limited       218
# spammer_warn          144
# tos_warn               91
# spammer_noinvite       84
# tos_lock               77
# locked                 54
# fraudster_att           5
# spammer_web             2
# spammer                 1
# Name: acct_type, dtype: int64

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings 
warnings.filterwarnings('ignore')
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 6.0)
import plotly.graph_objs as go
import chart_studio.plotly as py
# import cufflinks
pd.options.display.max_columns = 30
from IPython.core.interactiveshell import InteractiveShell
import plotly.figure_factory as ff
InteractiveShell.ast_node_interactivity = 'all'
from plotly.offline import iplot
# cufflinks.go_offline()
# cufflinks.set_config_file(world_readable=True, theme='pearl')
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook
output_notebook()
from collections import Counter
# import scattertext as st
# import spacy
from pprint import pprint
# import en_core_web_sm
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1005">Loading BokehJS ...</span>
#     </div>

# %%
df[df['acct_type'] == 'fraudster'].sample(10)
# Out:
#        acct_type  approx_payout_date  body_length  channels country currency  \
# 14131  fraudster          1331895600          455         5      HR      USD
# 8001   fraudster          1238904000         1857         6      GB      GBP
# 8658   fraudster          1334358000         1044         5      US      USD
# 9582   fraudster          1314838800          261         8      US      USD
# 10608  fraudster          1324699200         1937        11      US      USD
# 10507  fraudster          1302217200        18156         5      US      USD
# 1509   fraudster          1295222400          157         0      US      USD
# 11610  fraudster          1325851200          726         6      US      USD
# 11123  fraudster          1329958800          428         6      US      USD
# 7544   fraudster          1305802800          131         5      US      USD
#
#        delivery_method                                        description  \
# 14131              0.0  MARTINI BAND LIVE10.3.2012. @ GRIMZOC BAR BESP...
# 8001               NaN  VERY FEW TICKETS REMAININGBOOK NOW TO AVOID DI...
# 8658               0.0  Manno Bernini Garment Company will be hosting ...
# 9582               0.0  4 Rounds of Game/30 minutesEF: $85 ($80 LACC m...
# 10608              0.0  YAPPY HOLIDAYS!SANTA PAWS fido-friendly holida...
# 10507              0.0  VIP FREE TICKET OFFER BUY 1 VIP GET 1 FREE...B...
# 1509               0.0  I invite all to the party. I promise that will...
# 11610              0.0   5hr OPEN bar from 9:30pm to 2:30am!Hors d'oeu...
# 11123              0.0  Hello. I the chess player and I have decided t...
# 7544               0.0  Get your pre-memorial day party started with G...
#
#       email_domain  event_created   event_end  event_published  event_start  \
# 14131    gmail.com     1330881173  1331463600     1.330881e+09   1331438400
# 8001    lidf.co.uk     1236452739  1238472000     1.236454e+09   1238461200
# 8658       aol.com     1333211180  1333926000     1.333212e+09   1333742400
# 9582     ymail.com     1314255958  1314406800     1.314256e+09   1314399600
# 10608    yahoo.com     1322675758  1324267200     1.322676e+09   1324260000
# 10507      att.net     1290457125  1301785200     1.290708e+09   1299963600
# 1509     yahoo.com     1294519550  1294790400     1.294520e+09   1294736400
# 11610    gmail.com     1323719792  1325419200     1.323990e+09   1325394000
# 11123    yahoo.com     1329336165  1329526800     1.329337e+09   1329512400
# 7544     yahoo.com     1305143128  1305370800     1.305144e+09   1305342000
#
#        fb_published      gts  ...  \
# 14131             0   219.26  ...
# 8001              0     0.00  ...
# 8658              0   752.02  ...
# 9582              0   362.68  ...
# 10608             1    44.18  ...
# 10507             0    32.64  ...
# 1509              0   794.16  ...
# 11610             1  4705.25  ...
# 11123             0   805.76  ...
# 7544              0  5031.62  ...
#
#                                         previous_payouts  sale_duration  \
# 14131                                                 []            6.0
# 8001   [{'name': '', 'created': '2011-06-16 01:11:28'...           23.0
# 8658                                                  []            6.0
# 9582                                                  []            1.0
# 10608  [{'name': 'C.Cornish', 'created': '2011-10-30 ...           18.0
# 10507  [{'name': '', 'created': '2011-04-07 01:13:53'...          107.0
# 1509                                                  []            3.0
# 11610  [{'name': 'Midtown Bar & Restaurant LLC', 'cre...           16.0
# 11123  [{'name': '', 'created': '2012-03-07 03:12:33'...            2.0
# 7544                                                  []            2.0
#
#        sale_duration2 show_map  \
# 14131               6        1
# 8001               23        1
# 8658                6        1
# 9582                1        0
# 10608              18        1
# 10507             110        0
# 1509                3        0
# 11610              19        1
# 11123               2        1
# 7544                2        0
#
#                                             ticket_types  user_age  \
# 14131  [{'event_id': 3073697, 'cost': 10.0, 'availabi...         0
# 8001   [{'event_id': 301647, 'cost': 10.0, 'availabil...      1044
# 8658   [{'event_id': 3260195, 'cost': 280.0, 'availab...         0
# 9582   [{'event_id': 2087871, 'cost': 85.0, 'availabi...        14
# 10608  [{'event_id': 2575906, 'cost': 20.0, 'availabi...        62
# 10507  [{'event_id': 1067787, 'cost': 30.0, 'availabi...         0
# 1509   [{'event_id': 1182843, 'cost': 0.0, 'availabil...         0
# 11610  [{'event_id': 2629315, 'cost': 100.0, 'availab...      1017
# 11123  [{'event_id': 2961995, 'cost': 190.0, 'availab...        14
# 7544   [{'event_id': 1675347, 'cost': 600.0, 'availab...         0
#
#        user_created  user_type                   venue_address venue_country  \
# 14131    1330881172          1               Valentina Vodnika            HR
# 8001     1146260369          3                    30 Colonnade            GB
# 8658     1333211179          1            3770 Las Vegas Blvd.            US
# 9582     1313079424          1           196 Chasepointe Drive            US
# 10608    1317308021          1  411 North New River Drive East            US
# 10507    1290457124          3
# 1509     1294519549          1               8840 Cowenton Ave            US
# 11610    1235846234          4                  986 2nd Avenue            US
# 11123    1328136990          1           10768 Seacliff Circle            US
# 7544     1305143124          1                724 Nostrand Ave            US
#
#        venue_latitude venue_longitude  \
# 14131       45.805414       15.966844
# 8001        51.522928       -0.123980
# 8658        36.104189     -115.173217
# 9582        36.340033      -86.645186
# 10608       26.117985      -80.138447
# 10507        0.000000        0.000000
# 1509        39.388104      -76.440374
# 11610       40.756154      -73.967236
# 11123       26.397105      -80.216053
# 7544        40.673903      -73.950235
#
#                                               venue_name      venue_state  \
# 14131                                                      City of Zagreb
# 8001                                  The Horse Hospital  London, City Of
# 8658   Monte Carlo Resort & Casino - Grand Ballroom &...               NV
# 9582                               Absolution Chess Club               TN
# 10608                         Cruise Along The New River               FL
# 10507                                                TBA
# 1509                                          good party               MD
# 11610                                            Traffic               NY
# 11123                                                                  FL
# 7544                                  Secrets Night Clun               NY
#
#       fraud
# 14131  True
# 8001   True
# 8658   True
# 9582   True
# 10608  True
# 10507  True
# 1509   True
# 11610  True
# 11123  True
# 7544   True
#
# [10 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['acct_type', 'approx_payout_date', 'body_length', 'channels', 'country',
#        'currency', 'delivery_method', 'description', 'email_domain',
#        'event_created', 'event_end', 'event_published', 'event_start',
#        'fb_published', 'gts', 'has_analytics', 'has_header', 'has_logo',
#        'listed', 'name', 'name_length', 'num_order', 'num_payouts',
#        'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
#        'payee_name', 'payout_type', 'previous_payouts', 'sale_duration',
#        'sale_duration2', 'show_map', 'ticket_types', 'user_age',
#        'user_created', 'user_type', 'venue_address', 'venue_country',
#        'venue_latitude', 'venue_longitude', 'venue_name', 'venue_state',
#        'fraud'],
#       dtype='object')

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0,idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key= lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# top 20 words before removing stop words
common_words = get_top_n_words(df['description'], 20)
for word, freq in common_words:
    print(word, freq)
# Out:
# event 8852
# new 6286
# com 6113
# business 5978
# 00 5526
# 20 5011
# time 4979
# tickets 4967
# 30 4698
# day 4383
# www 4103
# ticket 3938
# 10 3918
# learn 3371
# join 3359
# make 3350
# course 3317
# people 3266
# available 3186
# information 3177

# %%
df.description
# Out:
# 0         Party Starz Entertaintment & Diverse Internat...
# 1        Join us for a quick, one-night, community-buil...
# 2        Teacher Training on the Desired Results Develo...
# 3        Affiliations are now due in respect of the 201...
# 4        Writers and filmmakers need to understand thei...
# 5        Come join the Bluegrass Stallions as they take...
# 6
# 7        WHEN JEKYLL MET HYDEThe Magnetic Theatre in Th...
# 8        Merchants Exchange Productions and the Julia M...
# 9        WHEN JEKYLL MET HYDEThe Magnetic Theatre in Th...
# 10       What are some potential warning signs of abuse...
# 11       monkeyface eel champion, blogger and street pe...
# 12       You’ve got a profile on LinkedIn – Now What?Th...
# 13       Enchantment: The Art of Changing Hearts, Minds...
# 14       Top celebrity & editorial stylists Ilaria Urbi...
# 15       "An education film that gets it"Washington Pos...
# 16       "An education film that gets it"Washington Pos...
# 17
# 18       Rob Holmes is one of the world's best online i...
# 19       Lookingforanewexperience? Come and be a part o...
# 20       Since its inception ÉCU- The European Independ...
# 21       Private drum lessons with Jim Riley of Rascal ...
# 22       This retreat is for guys working in the world ...
# 23       Cultures, Strategic Markets, & Fair Housing We...
# 24       This event will sell out. Reserve your spot fo...
# 25       Cub Scouts and Boy Scouts alike will find this...
# 26       Welcome 5th Annual Earth Transformation Confer...
# 27       Tickets to Chicago Forward: A Conversation wit...
# 28       Come and Join the #1 Botox and Dermal Fillers ...
# 29       DISTRIKT is a San Francisco based Burning Man ...
#                                ...
# 14307
# 14308    Bethel Music Spring Tour: Charlotte Night of W...
# 14309    The second Brazil Wind Energy Conference, BWEC...
# 14310    LADIES!!!  You and your guests are invited to ...
# 14311    This powerful seminar equips individuals, chur...
# 14312    2013 Winfield Criterium Weekend - July 27, 201...
# 14313
# 14314    Day 1: February 13, 2013| 8:30 AM - 4:30 PMDay...
# 14315    Kris & EikiTeachers workshopSunday 13.15-14.45...
# 14316    After the success of a solid 365 days in the y...
# 14317    STREAM THE NEW ALBUM UNITED STATES OF GOD DES ...
# 14318    Help us produce this incredible experience. Th...
# 14319         Overview     I     What to expect     I  ...
# 14320    Saltmine Theatre Company's production of 'Thre...
# 14321    Content strategy, marketing, creation, curatio...
# 14322
# 14323    On behalf of Computing At School and the Netwo...
# 14324    LEGION FETISH EVENTS IS BACK AND STRONGER  WE ...
# 14325    You are cordially invited to join us for a onc...
# 14326    Demonstration of Mediumship by Sandie Byrne Me...
# 14327    Anti-Racist Pedagogy Across the Curriculum Wor...
# 14328    What you will be shown on the day...This 1 hou...
# 14329    What you will be shown on the day...This 1 hou...
# 14330
# 14331    Mastered the basics of IntelliPlex and now loo...
# 14332    Celebrates this wonderful holiday with the fri...
# 14333    2013 Scientist of the YearHonoring  Eric J. To...
# 14334    What a way to start off your Mother's Day ladi...
# 14335    Valentines Day At Salsa Con Fuego Salsa Con Fu...
# 14336
# Name: description, Length: 14337, dtype: object

# %%
# top 20 words after removing stop words
common_words1 = get_top_n_words(df['description'], 20)
for word, freq in common_words1:
    print(word, freq)
# Out:
# event 8854
# new 6288
# business 5985
# 20 5769
# pm 5597
# time 4985
# tickets 4981
# day 4390
# ticket 3942
# learn 3373
# join 3369
# make 3351
# course 3319
# people 3267
# available 3187
# information 3179
# bring 3106
# class 3100
# year 2974
# workshop 2973

# %%
common_words_fraud = get_top_n_words(df['description'][df['fraud']==True], 20)
for word, freq in common_words_fraud:
    print(word, freq)
# Out:
# event 373
# tickets 316
# et 304
# party 272
# time 251
# new 249
# la 245
# help 238
# le 230
# course 227
# les 207
# du 195
# pm 188
# ticket 188
# night 184
# des 182
# best 181
# day 180
# world 178
# free 174

# %%
common_words_clean = get_top_n_words(df['description'][df['fraud']==False], 20)
for word, freq in common_words_clean:
    print(word, freq)
# Out:
# event 8481
# new 6039
# business 5851
# 20 5640
# pm 5409
# time 4734
# tickets 4665
# day 4210
# ticket 3754
# join 3276
# learn 3271
# make 3229
# information 3097
# people 3095
# course 3092
# available 3034
# class 2995
# bring 2945
# workshop 2836
# year 2831

# %%
# need to remove all URL
# df.description = df.description.apply(lambda x: remove_link(x))

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
common_bigrams = get_top_n_bigram(df['description'], 20)
for word, freq in common_bigrams:
    print(word, freq)
# Out:
# of the 12829
# will be 9447
# in the 8493
# to the 6234
# at the 6228
# on the 5150
# for the 4973
# if you 4165
# and the 3875
# how to 3749
# you will 2846
# to be 2779
# with the 2729
# the event 2712
# you can 2522
# from the 2433
# is the 2229
# we will 2221
# 20 20 2135
# you are 2099

# %%
common_bigrams_fraud = get_top_n_bigram(df['description'][df['fraud']==True], 20)
for word, freq in common_bigrams_fraud:
    print(word, freq)
# Out:
# of the 558
# will be 500
# in the 435
# to the 310
# for the 227
# at the 217
# on the 196
# how to 156
# if you 145
# and the 139
# to be 131
# with the 120
# you will 116
# the event 116
# this is 113
# is the 113
# can be 104
# you can 101
# to help 100
# we will 98

# %%
common_bigrams_clean = get_top_n_bigram(df['description'][df['fraud']==False], 20)
for word, freq in common_bigrams_clean:
    print(word, freq)
# Out:
# of the 12271
# will be 8947
# in the 8058
# at the 6011
# to the 5924
# on the 4954
# for the 4746
# if you 4020
# and the 3736
# how to 3593
# you will 2730
# to be 2648
# with the 2609
# the event 2596
# you can 2421
# from the 2343
# 20 20 2133
# we will 2123
# is the 2116
# you are 2019

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
common_trigrams = get_top_n_trigram(df['description'], 20)
for word, freq in common_trigrams:
    print(word, freq)
# Out:
# 20 20 20 1558
# as well as 1178
# one of the 1015
# for more information 966
# join us for 961
# at the door 925
# if you have 808
# if you are 727
# learn how to 709
# there will be 703
# some of the 552
# to the event 533
# you will be 528
# be able to 514
# 0a 20 20 511
# will be available 489
# would like to 464
# you need to 462
# we will be 461
# will be provided 449

# %%
common_trigrams_fraud = get_top_n_trigram(df['description'][df['fraud']==True], 20)
for word, freq in common_trigrams_fraud:
    print(word, freq)
# Out:
# as well as 55
# will be available 48
# one of the 40
# there will be 39
# if you have 36
# will help you 35
# to help you 34
# for more info 33
# would like to 29
# this event is 28
# we will be 27
# look at how 27
# food and wine 27
# you will be 26
# some of the 26
# be able to 26
# your personal taste 26
# interesting look at 26
# feel free to 25
# learn how to 25

# %%
common_trigrams_clean = get_top_n_trigram(df['description'][df['fraud']==False], 20)
for word, freq in common_trigrams_clean:
    print(word, freq)
# Out:
# 20 20 20 1558
# as well as 1123
# one of the 975
# for more information 946
# join us for 943
# at the door 910
# if you have 772
# if you are 709
# learn how to 684
# there will be 664
# some of the 526
# to the event 519
# 0a 20 20 511
# you will be 502
# be able to 488
# you need to 443
# will be available 441
# will be provided 436
# would like to 435
# we will be 434

# %%
df.loc[df[]]
